# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import pandas as pd
#This tool is used for automating web-based application testing to verify that it performs expectedly.
#Beautiful Soup is a Python package for parsing HTML and XML documents (including having malformed markup, i.e. non-closed tags, so named after tag soup). It creates a parse tree for parsed pages that can be used to extract data from HTML, which is useful for web scraping.
#The requests module allows you to send HTTP requests using Python

# %%
driver = webdriver.Chrome()
url = 'https://www.pararius.com/apartments/amsterdam?ac=1'
response = requests.get(url)
driver.maximize_window()
driver.get(url)

time.sleep(5)
content = driver.page_source.encode('utf-8').strip()
soup = BeautifulSoup(content, "html.parser")
lists = soup.find_all('section', class_="listing-search-item")

# %%
title = []
location = []
price = []
area = []

# %%
for list in lists:

    if list.find('a', class_="listing-search-item__link listing-search-item__link--title"):
        title.append(list.find('a', class_="listing-search-item__link listing-search-item__link--title").text.replace('\n', ''))
    else:
        title.append('')

    if list.find('div', class_="listing-search-item__sub-title"):
        location.append(list.find('div', class_="listing-search-item__sub-title").text.replace('\n', ''))
    else:
        location.append('')

    if list.find('div', class_="listing-search-item__price"):
        price.append(list.find('div', class_="listing-search-item__price").text.replace('\n', ''))
    else:
        price.append('')

    if list.find('ul', class_="illustrated-features illustrated-features--compact"):
        area.append(list.find('ul', class_="illustrated-features illustrated-features--compact").text.replace('\n', ''))
    else:
        area.append('')

# %%
data = pd.DataFrame({'title':title, 'location':location, 'price':price, 'area':area})
pd.set_option('display.max_columns', None)
print(data)
# Out:
#                                                 title  \
# 0                           Apartment Wolbrantsker...
# 1                           Apartment Deurloostraa...
# 2                           Apartment Krommertstra...
# 3                           Apartment Buitenvelder...
# 4                           Apartment Warmoesstraa...
# 5                           Apartment Shackletonst...
# 6                           Apartment Bijlmerdreef...
# 7                           Apartment Dufaystraat ...
# 8                           Apartment Govert Flinc...
# 9                           Apartment Nieuwe Uilen...
# 10                          Apartment Graafschapst...
# 11                          Apartment Veembroederh...
# 12                          Apartment Pieter de Ho...
# 13                          Apartment Plantage Ker...
# 14                          Apartment Da Costakade...
# 15                          Apartment Karel du Jar...
# 16                          Apartment Jan van Gale...
# 17                          Apartment Kanaalstraat...
# 18                          Apartment Kanaalstraat...
# 19                          Apartment Westerdok   ...
# 20                          Apartment Roerstraat 4...
# 21                          Apartment Krommertstra...
# 22                          Apartment Zeeburgerkad...
# 23                          Apartment Jan van Duiv...
# 24                          Apartment Funenpark 18...
# 25                          Apartment Ter Haarstra...
# 26                          Apartment Govert Flinc...
# 27                          House John Campbellstr...
# 28                          Apartment Wibautstraat...
# 29                          Apartment Rozengracht ...
# 30                          Apartment Kinkerstraat...
# 31                          Apartment Van Eeghenla...
#
#                                              location  \
# 0               1069 DA Amsterdam (Osdorp-Midden) ...
# 1               1078 JJ Amsterdam (Scheldebuurt)  ...
# 2               1056 TS Amsterdam (Geuzenbuurt)   ...
# 3               1082 VB Amsterdam (Buitenveldert-W...
# 4               1012 JD Amsterdam (Burgwallen-Oude...
# 5               1056 RM Amsterdam (Van Galenbuurt)...
# 6               1103 TW Amsterdam (Bijlmer Oost (E...
# 7               1075 GS Amsterdam (Willemspark)   ...
# 8               1073 CD Amsterdam (Oude Pijp)
# 9               1011 LM Amsterdam (Nieuwmarkt/Last...
# 10              1079 PE Amsterdam (Scheldebuurt)  ...
# 11              1019 HD Amsterdam (Oostelijk Haven...
# 12              1071 ED Amsterdam (Museumkwartier)...
# 13              1018 CW Amsterdam (Weesperbuurt/Pl...
# 14              1052 SH Amsterdam (Da Costabuurt) ...
# 15              1072 SE Amsterdam (Nieuwe Pijp)   ...
# 16               1056 CD Amsterdam (Landlust)
# 17              1054 XN Amsterdam (Overtoomse Slui...
# 18              1054 XN Amsterdam (Overtoomse Slui...
# 19              1013 BH Amsterdam (Haarlemmerbuurt...
# 20              1078 LJ Amsterdam (Scheldebuurt)  ...
# 21              1056 TS Amsterdam (Geuzenbuurt)   ...
# 22              1019 HG Amsterdam (Oostelijk Haven...
# 23              1067 MT Amsterdam (Geuzenveld)    ...
# 24              1018 AK Amsterdam (Oostelijke Eila...
# 25              1053 LJ Amsterdam (Da Costabuurt) ...
# 26              1073 CH Amsterdam (Oude Pijp)
# 27              1086 ZT Amsterdam (IJburg West)   ...
# 28              1091 GR Amsterdam (Weesperzijde)  ...
# 29                1016 NL Amsterdam (Jordaan)
# 30              1053 GC Amsterdam (Kinkerbuurt)   ...
# 31              1071 EL Amsterdam (Museumkwartier)...
#
#                                            price  \
# 0                   €2,495 per month
# 1                   €2,495 per month
# 2                   €1,650 per month
# 3                   €1,950 per month
# 4                   €2,150 per month
# 5                   €1,950 per month
# 6                   €1,750 per month
# 7                   €2,450 per month
# 8                   €3,500 per month
# 9                   €1,850 per month
# 10                  €2,400 per month
# 11                  €3,500 per month
# 12                  €3,700 per month
# 13                  €2,550 per month
# 14                  €1,900 per month
# 15                  €2,250 per month
# 16                  €2,650 per month
# 17                  €2,250 per month
# 18                  €1,950 per month
# 19                  €2,900 per month
# 20                  €2,500 per month
# 21                  €1,550 per month
# 22                  €2,000 per month
# 23                  €1,795 per month
# 24                  €2,750 per month
# 25                  €2,000 per month
# 26                  €2,800 per month
# 27                  €3,500 per month
# 28                  €2,150 per month
# 29                  €1,850 per month
# 30                  €1,750 per month
# 31                  €3,200 per month
#
#                                      area
# 0                132 m²3 roomsUpholstered
# 1                   80 m²3 roomsFurnished
# 2                 30 m²2 roomsUpholstered
# 3                   88 m²3 roomsFurnished
# 4    65 m²2 roomsUpholstered or furnished
# 5                 55 m²3 roomsUpholstered
# 6                   80 m²3 roomsFurnished
# 7                   70 m²3 roomsFurnished
# 8                130 m²4 roomsUpholstered
# 9                   55 m²2 roomsFurnished
# 10                  95 m²3 rooms2001-2010
# 11  157 m²6 roomsUpholstered or furnished
# 12                 129 m²4 roomsFurnished
# 13                  90 m²3 roomsFurnished
# 14                  65 m²3 rooms1906-1930
# 15                  62 m²3 rooms1906-1930
# 16                      75 m²3 rooms15 m²
# 17                      55 m²3 rooms20 m²
# 18                  55 m²2 rooms2001-2010
# 19                      110 m²3 rooms2008
# 20                  74 m²3 roomsFurnished
# 21                30 m²2 roomsUpholstered
# 22               100 m²3 roomsUpholstered
# 23                       90 m²3 rooms2002
# 24  100 m²3 roomsUpholstered or furnished
# 25                58 m²3 roomsUpholstered
# 26                97 m²4 roomsUpholstered
# 27                 200 m²7 roomsFurnished
# 28                  85 m²2 roomsFurnished
# 29                       40 m²2 rooms1893
# 30                       45 m²2 rooms1898
# 31                  98 m²3 roomsFurnished
